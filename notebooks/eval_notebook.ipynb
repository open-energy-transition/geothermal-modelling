# %%
import pypsa
import numpy as np
import pandas as pd
import geopandas as gpd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
n = pypsa.Network(Path.cwd().parent / 'workflow' / 'pypsa-earth' / 'networks' / 'US_2021' / 'elec_s_10_ec.nc')
# Out:
# c:\Users\lukas\miniforge3\envs\pypsa-earth\lib\site-packages\pypsa\components.py:318: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attrs.loc[bool_b, "default"] = attrs.loc[bool_b].isin({True, "True"})
# c:\Users\lukas\miniforge3\envs\pypsa-earth\lib\site-packages\pypsa\components.py:318: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attrs.loc[bool_b, "default"] = attrs.loc[bool_b].isin({True, "True"})
# ...

# %%
Path.cwd()
# Out:
# WindowsPath('c:/Users/lukas/OneDrive/Desktop/projects/pis/correct_version/geothermal-modelling/notebooks')

# %%
df = pd.read_csv(Path.cwd().parent / 'workflow' / 'pypsa-earth' / 'dummy' / 'egs_dummy_data.csv', index_col=0)
# df['capex'] *= 2e3
# df['opex'] *= 1e-1
# df['available_capacity'] = np.random.normal(10, 0.2, len(df))

# %%
print(df['available_capacity'].min())
print(df['available_capacity'].sum())
# Out:
# 9.2363051772401
# 87030.10071296072

# %%
df = df.rename(columns={
    'capex': 'capex[$/kW]',
    'opex': 'opex[$/kWh]',
    'available_capacity': 'available_capacity[MW]'
})

# %%
# df.to_csv(Path.cwd().parent / 'workflow' / 'pypsa-earth' / 'dummy' / 'egs_dummy_data.csv')

# %%
import geopandas as gpd

regions = gpd.read_file(Path.cwd().parent / 'workflow' / 'pypsa-earth' / 'dummy' / 'regions.geojson')
# Out:
# <AxesSubplot:>

# %%
ss = pd.DataFrame(np.random.normal(size=(2,2)))
bus = 'US0 1'

f"{bus} " + pd.Index(range(len(ss)), dtype=str)
# Out:
# Index(['US0 1 0', 'US0 1 1'], dtype='object')

# %%
path = Path.cwd().parent / 'workflow' / 'pypsa-earth' / 'networks' / 'US_2021' / 'elec_s_10_ec_lcopt_24H.nc'
n = pypsa.Network(path)
# Out:
# c:\Users\lukas\miniforge3\envs\pypsa-earth\lib\site-packages\pypsa\components.py:318: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attrs.loc[bool_b, "default"] = attrs.loc[bool_b].isin({True, "True"})
# c:\Users\lukas\miniforge3\envs\pypsa-earth\lib\site-packages\pypsa\components.py:318: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attrs.loc[bool_b, "default"] = attrs.loc[bool_b].isin({True, "True"})
# ...

# %%
n.links
# Out:
#                         tag_type  v_nom  num_parallel  tag_frequency  \
# Link
# convert_2448_5364                   NaN           NaN            NaN
# convert_6868_11921                  NaN           NaN            NaN
# 23952+2                             NaN           NaN            NaN
# 23953+2                             NaN           NaN            NaN
# 5575+5                              NaN           NaN            NaN
# ...                          ...    ...           ...            ...
# US.6_1_AC 3 EGS well                NaN           NaN            NaN
# US.6_1_AC 0 EGS surface             NaN           NaN            NaN
# US.6_1_AC 1 EGS surface             NaN           NaN            NaN
# US.6_1_AC 2 EGS surface             NaN           NaN            NaN
# US.6_1_AC 3 EGS surface             NaN           NaN            NaN
#
#                                             bus0                     bus1  \
# Link
# ...

# %%
n.buses.shape
# Out:
# (249, 13)

# %%
n.buses.loc[n.buses.carrier == 'AC']
# Out:
#             v_nom country carrier           x          y control  \
# Bus
# US.10_1_AC  380.0      US      AC  -82.832394  28.998241   Slack
# US.11_1_AC  380.0      US      AC  -83.523182  32.755900      PQ
# US.12_1_AC  380.0      US      AC -151.791380  23.474580      PQ
# US.13_1_AC  380.0      US      AC -113.872269  43.809350      PQ
# US.14_1_AC  380.0      US      AC  -89.131639  40.152395      PQ
# US.15_1_AC  380.0      US      AC  -86.286628  39.922350      PQ
# US.16_1_AC  380.0      US      AC  -93.666689  42.054737      PQ
# US.17_1_AC  380.0      US      AC  -97.724355  38.384720      PQ
# US.18_1_AC  380.0      US      AC  -85.453372  37.526056      PQ
# US.19_1_AC  380.0      US      AC  -91.927898  31.139710      PQ
# US.1_1_AC   380.0      US      AC  -86.668484  32.846655      PQ
# US.20_1_AC  380.0      US      AC  -69.684042  44.335996      PQ
# US.21_1_AC  380.0      US      AC  -76.804054  39.047575      PQ
# ...
